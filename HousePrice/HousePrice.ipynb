# %%
import pandas as pd
import numpy as np

# %%
data=pd.read_csv("train.csv")
test=pd.read_csv("test.csv")
test_ids = test["Id"]

# %%
data.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities  ... PoolArea PoolQC Fence MiscFeature MiscVal MoSold  \
# 0         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 1         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      5
# 2         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      9
# 3         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 4         Lvl    AllPub  ...        0    NaN   NaN         NaN       0     12
#
#   YrSold  SaleType  SaleCondition  SalePrice
# ...

# %%
data.shape
# Out:
# (1460, 81)

# %%
# check null values for every column
def check_null_values(data):
    null_count = data.isna().sum()  # Count nulls for each column
    for column, count in null_count.items():
        print(f" '{column}' : {count}")

check_null_values(data)
# Out:
#  'Id' : 0
#  'MSSubClass' : 0
#  'MSZoning' : 0
#  'LotFrontage' : 259
#  'LotArea' : 0
#  'Street' : 0
#  'Alley' : 1369
#  'LotShape' : 0
#  'LandContour' : 0
#  'Utilities' : 0
#  'LotConfig' : 0
#  'LandSlope' : 0
#  'Neighborhood' : 0
#  'Condition1' : 0
#  'Condition2' : 0
#  'BldgType' : 0
#  'HouseStyle' : 0
#  'OverallQual' : 0
#  'OverallCond' : 0
#  'YearBuilt' : 0
#  'YearRemodAdd' : 0
#  'RoofStyle' : 0
#  'RoofMatl' : 0
#  'Exterior1st' : 0
#  'Exterior2nd' : 0
#  'MasVnrType' : 872
#  'MasVnrArea' : 8
#  'ExterQual' : 0
#  'ExterCond' : 0
#  'Foundation' : 0
#  'BsmtQual' : 37
#  'BsmtCond' : 37
#  'BsmtExposure' : 38
#  'BsmtFinType1' : 37
#  'BsmtFinSF1' : 0
#  'BsmtFinType2' : 38
#  'BsmtFinSF2' : 0
#  'BsmtUnfSF' : 0
#  'TotalBsmtSF' : 0
#  'Heating' : 0
#  'HeatingQC' : 0
#  'CentralAir' : 0
#  'Electrical' : 1
#  '1stFlrSF' : 0
#  '2ndFlrSF' : 0
#  'LowQualFinSF' : 0
#  'GrLivArea' : 0
#  'BsmtFullBath' : 0
#  'BsmtHalfBath' : 0
#  'FullBath' : 0
# ...

# %%
data.shape
# Out:
# (1460, 81)

# %%
#delete 2 columns cause morethan 90% columns are null
col = ['MiscFeature','Alley']
def delete_columns(data):
     for column in col:
        if column in data.columns:  # Check if column exists in the DataFrame
            data = data.drop(column, axis=1)
     return data

data=delete_columns(data)

# %%
data.shape
# Out:
# (1460, 79)

# %%
def fill_non_numeric_columns(data):
    for col in data.select_dtypes(exclude=['number']).columns:
        data[col]=data[col].fillna('missing value')
    return data

data=fill_non_numeric_columns(data)

# %%
def fill_numeric_columns(data):
    for col in data.select_dtypes(include=['number']).columns:
        value=data[col].median()
        data[col]=data[col].fillna(value)
    return data

data=fill_numeric_columns(data)

# %%
check_null_values(data)
# Out:
#  'Id' : 0
#  'MSSubClass' : 0
#  'MSZoning' : 0
#  'LotFrontage' : 0
#  'LotArea' : 0
#  'Street' : 0
#  'LotShape' : 0
#  'LandContour' : 0
#  'Utilities' : 0
#  'LotConfig' : 0
#  'LandSlope' : 0
#  'Neighborhood' : 0
#  'Condition1' : 0
#  'Condition2' : 0
#  'BldgType' : 0
#  'HouseStyle' : 0
#  'OverallQual' : 0
#  'OverallCond' : 0
#  'YearBuilt' : 0
#  'YearRemodAdd' : 0
#  'RoofStyle' : 0
#  'RoofMatl' : 0
#  'Exterior1st' : 0
#  'Exterior2nd' : 0
#  'MasVnrType' : 0
#  'MasVnrArea' : 0
#  'ExterQual' : 0
#  'ExterCond' : 0
#  'Foundation' : 0
#  'BsmtQual' : 0
#  'BsmtCond' : 0
#  'BsmtExposure' : 0
#  'BsmtFinType1' : 0
#  'BsmtFinSF1' : 0
#  'BsmtFinType2' : 0
#  'BsmtFinSF2' : 0
#  'BsmtUnfSF' : 0
#  'TotalBsmtSF' : 0
#  'Heating' : 0
#  'HeatingQC' : 0
#  'CentralAir' : 0
#  'Electrical' : 0
#  '1stFlrSF' : 0
#  '2ndFlrSF' : 0
#  'LowQualFinSF' : 0
#  'GrLivArea' : 0
#  'BsmtFullBath' : 0
#  'BsmtHalfBath' : 0
#  'FullBath' : 0
#  'HalfBath' : 0
#  'BedroomAbvGr' : 0
# ...

# %%
from sklearn.preprocessing import LabelEncoder
def label_encoding(data):
    lc=LabelEncoder()
    for col in data.select_dtypes(exclude=['number']).columns:
        data[col]=lc.fit_transform(data[col])
    return data
data = label_encoding(data)

# %%
x = data.drop('SalePrice', axis=1)
y = data['SalePrice']
from sklearn.model_selection import train_test_split
xtrain, xtest, ytrain, ytest = train_test_split(x, y, test_size=0.2, random_state=42)

# %%
data.head()
# Out:
#    Id  MSSubClass  MSZoning  LotFrontage  LotArea  Street  LotShape  \
# 0   1          60         3         65.0     8450       1         3
# 1   2          20         3         80.0     9600       1         3
# 2   3          60         3         68.0    11250       1         0
# 3   4          70         3         60.0     9550       1         0
# 4   5          60         3         84.0    14260       1         0
#
#    LandContour  Utilities  LotConfig  ...  ScreenPorch  PoolArea  PoolQC  \
# 0            3          0          4  ...            0         0       3
# 1            3          0          2  ...            0         0       3
# 2            3          0          4  ...            0         0       3
# 3            3          0          0  ...            0         0       3
# 4            3          0          2  ...            0         0       3
#
#    Fence  MiscVal  MoSold  YrSold  SaleType  SaleCondition  SalePrice
# ...

# %%
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler

# Standardize the data (fit on training data, transform both train and test)
scaler = StandardScaler()
xtrain_scaled = scaler.fit_transform(xtrain)
xtest_scaled = scaler.transform(xtest)

# Apply PCA (fit on training data, transform both train and test)
pca = PCA(n_components=0.95)  # Retain 95% of variance
xtrain_pca = pca.fit_transform(xtrain_scaled)
xtest_pca = pca.transform(xtest_scaled)

# Check the shapes
print("Original Train Shape:", xtrain.shape)
print("PCA Train Shape:", xtrain_pca.shape)
print("Original Test Shape:", xtest.shape)
print("PCA Test Shape:", xtest_pca.shape)
# Out:
# Original Train Shape: (1168, 78)
# PCA Train Shape: (1168, 58)
# Original Test Shape: (292, 78)
# PCA Test Shape: (292, 58)

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import root_mean_squared_error, r2_score
regression = LinearRegression()

# %%
regression.fit(xtrain_pca,ytrain)
# Out:
# LinearRegression()

# %%
ypred = regression.predict(xtest_pca)

# %%
print(r2_score(ytest,ypred))
print(root_mean_squared_error(ytest,ypred))
# Out:
# 0.8472727516514952
# 34226.71201794168

# %%
test = label_encoding(test)
test.head()
# Out:
#      Id  MSSubClass  MSZoning  LotFrontage  LotArea  Street  Alley  LotShape  \
# 0  1461          20         2         80.0    11622       1      2         3
# 1  1462          20         3         81.0    14267       1      2         0
# 2  1463          60         3         74.0    13830       1      2         0
# 3  1464          60         3         78.0     9978       1      2         0
# 4  1465         120         3         43.0     5005       1      2         0
#
#    LandContour  Utilities  ...  ScreenPorch  PoolArea  PoolQC  Fence  \
# 0            3          0  ...          120         0       2      2
# 1            3          0  ...            0         0       2      4
# 2            3          0  ...            0         0       2      2
# 3            3          0  ...            0         0       2      4
# 4            1          0  ...          144         0       2      4
#
#    MiscFeature  MiscVal  MoSold  YrSold  SaleType  SaleCondition
# ...

# %%
test=delete_columns(test)

# %%
data.shape
# Out:
# (1460, 79)

# %%
test=fill_numeric_columns(test)
test.shape
# Out:
# (1459, 78)

# %%
# Standardize the data (fit on training data, transform both train and test)
scaler = StandardScaler()
testscale = scaler.fit_transform(test)


# Apply PCA (fit on training data, transform both train and test)
pca = PCA(n_components=0.95)  # Retain 95% of variance
testfinal = pca.fit_transform(testscale)

# %%
submission_pred = regression.predict(testfinal)

# %%
testfinal=pd.DataFrame(testfinal)

# %%
df=pd.DataFrame({"Id":test_ids.values,'SalePrice':submission_pred})

# %%
df.to_csv("house-priceTwo",index=False)
